# %%
import matplotlib

# %%
import matplotlib.pyplot as plt 
  
# x axis values 
x = [1,2,3] 
# corresponding y axis values 
y = [2,4,1] 
  
# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('My first graph!') 
  
# function to show the plot 
plt.show()

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]

# %%
print(type(jfm_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(jfm_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(jfm_data)
#
# NameError: name 'jfm_data' is not defined

# %%
import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]

# %%
print(jfm_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(jfm_data)
#
# NameError: name 'jfm_data' is not defined

# %%
import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]

# %%
print(jfm_data.Unit.tolist())
# Out:
# [342, 389, 401, 385, 427, 305, 344, 397, 422, 297, 456, 444, 401, 395, 434, 456, 402, 412, 322, 383, 291, 350, 293, 216, 324, 375, 359, 391, 355, 369, 379, 422, 373, 314, 327, 288, 361, 379, 307, 252, 341, 573, 212, 189, 177, 243, 183, 293, 237, 293, 293, 256, 215, 316, 308, 319, 165, 320, 356, 320, 317, 335, 386, 378, 334, 337, 328, 354, 320, 320, 423, 324, 275, 361, 283, 264, 310, 320, 278, 395, 320, 335, 315, 291, 414, 334, 321, 283, 300, 354, 302, 373, 520, 219, 170, 188, 225, 220, 355, 254, 276, 282, 275, 252, 246, 308, 254, 255, 276]

# %%
print(jfm_data.date.tolist())
# Out:
# [Timestamp('2022-06-09 00:00:00'), Timestamp('2022-06-16 00:00:00'), Timestamp('2020-06-23 00:00:00'), Timestamp('2022-06-30 00:00:00'), Timestamp('2022-07-07 00:00:00'), Timestamp('2022-07-14 00:00:00'), Timestamp('2022-07-21 00:00:00'), Timestamp('2022-07-28 00:00:00'), Timestamp('2022-08-04 00:00:00'), Timestamp('2022-08-11 00:00:00'), Timestamp('2022-08-18 00:00:00'), Timestamp('2022-07-25 00:00:00'), Timestamp('2022-09-01 00:00:00'), Timestamp('2022-09-08 00:00:00'), Timestamp('2022-09-15 00:00:00'), Timestamp('2022-09-22 00:00:00'), Timestamp('2022-09-29 00:00:00'), Timestamp('2022-10-06 00:00:00'), Timestamp('2022-10-13 00:00:00'), Timestamp('2022-10-21 00:00:00'), Timestamp('2022-09-28 00:00:00'), Timestamp('2022-11-03 00:00:00'), Timestamp('2022-11-10 00:00:00'), Timestamp('2022-11-17 00:00:00'), Timestamp('2022-11-24 00:00:00'), Timestamp('2022-12-01 00:00:00'), Timestamp('2022-12-08 00:00:00'), Timestamp('2022-12-15 00:00:00'), Timestamp('2022-12-22 00:00:00'), Timestamp('
# ...

# %%
import matplotlib.pyplot as plt 
'''
import numpy as np

xpoints = np.array(jfm_data.date.tolist())
ypoints = np.array(jfm_data.Unit.tolist())

plt.plot(xpoints.sort(), ypoints)
plt.show()

'''
# x axis values 
x =  jfm_data.date.tolist()
# corresponding y axis values 
y = jfm_data.Unit.tolist()
  
# plotting the points
#fig = plt.figure(figsize=(50, 10))
#ax = fig.add_subplot(1)
plt.plot(x, y) 
#plt.xscale('log', basex=2)
  
# naming the x axis 
plt.xlabel('Weekly time') 
# naming the y axis 
plt.ylabel('JFM Units') 
  
# giving a title to my graph 
plt.title('JFM Progress') 

#plt.xlim(0, 50)
#plt.ylim(0, 1)
  
# function to show the plot 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 20
#      15 y = jfm_data.Unit.tolist()
#      17 # plotting the points
#      18 #fig = plt.figure(figsize=(50, 10))
#      19 #ax = fig.add_subplot(1)
# ---> 20 plt.plot(x.sort(), y)
#      21 #plt.xscale('log', basex=2)
#      22
#      23 # naming the x axis
#      24 plt.xlabel('Weekly time')
#
# File ~/development/lib/python3.12/site-packages/matplotlib/pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
# ...

# %%
import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]

# %%
import matplotlib.pyplot as plt 
import datetime as dt
import numpy as np

# create dataframe
 
dataframe = pd.DataFrame({'date_of_week': np.array(jfm_data.date.tolist()),
                          'units': jfm_data.Unit.tolist() })


plt.plot(dataframe.date_of_week, dataframe.units)

plt.title('JFM Progress')

plt.xticks(rotation=30, ha='right')

plt.xlabel('Time')
plt.ylabel('Units')
# Out:
# Text(0, 0.5, 'Units')

# %%
import pandas as pd
import matplotlib.pyplot as plt

date_time = jfm_data.date.tolist()
date_time = pd.to_datetime(date_time)
data = jfm_data.Unit.tolist()

DF = pd.DataFrame()
DF['value'] = data
DF = DF.set_index(date_time)
plt.plot(DF)
plt.gcf().autofmt_xdate()
plt.show()

# %%
import matplotlib.pyplot as plt 
import datetime as dt
import numpy as np

# create dataframe

x = jfm_data.date.to_list()

y = jfm_data.Unit.tolist()

processed_x = []

for element in x:
    #print(element.to_pydatetime)
    ts = pd.Timestamp(element)
    #print(ts.to_pydatetime)
    processed_x.append(ts.to_pydatetime)

#print(processed_x)
 
dataframe = pd.DataFrame({'date_of_week': np.array(x),
                          'units': y })

#dataframe.set_index('date_of_week', inplace=True)


plt.plot(dataframe.date_of_week, dataframe.units)

plt.title('JFM Progress')

plt.xticks(rotation=30, ha='right')

plt.xlabel('Time')
plt.ylabel('Units')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/7y/4f_3_8x96c5bh2vppz_hvylh0000gp/T/ipykernel_57968/3632736591.py in ?()
#      23
#      24 dataframe.set_index('date_of_week', inplace=True)
#      25
#      26
# ---> 27 plt.plot(dataframe.date_of_week, dataframe.units)
#      28
#      29 plt.title('JFM Progress')
#      30
#
# ~/development/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'date_of_week'

# %%
# Out:
#   Cell In[22], line 2
#     for i in range(7)]
#                       ^
# SyntaxError: incomplete input

# %%
import datetime
import numpy as np
np.array([datetime.datetime(2021, 11, i+1)
                                                    for i in range(7)])
# Out:
# array([datetime.datetime(2021, 11, 1, 0, 0),
#        datetime.datetime(2021, 11, 2, 0, 0),
#        datetime.datetime(2021, 11, 3, 0, 0),
#        datetime.datetime(2021, 11, 4, 0, 0),
#        datetime.datetime(2021, 11, 5, 0, 0),
#        datetime.datetime(2021, 11, 6, 0, 0),
#        datetime.datetime(2021, 11, 7, 0, 0)], dtype=object)

# %%
import datetime
import numpy as np
np.array([datetime.datetime(2021, 11, i+1)
                                                    for i in range(7)])
# Out:
# array([datetime.datetime(2021, 11, 1, 0, 0),
#        datetime.datetime(2021, 11, 2, 0, 0),
#        datetime.datetime(2021, 11, 3, 0, 0),
#        datetime.datetime(2021, 11, 4, 0, 0),
#        datetime.datetime(2021, 11, 5, 0, 0),
#        datetime.datetime(2021, 11, 6, 0, 0),
#        datetime.datetime(2021, 11, 7, 0, 0)], dtype=object)

# %%
import matplotlib.pyplot as plt 
import datetime as dt
import numpy as np

# create dataframe

x = jfm_data.date.to_list()

y = jfm_data.Unit.tolist()

processed_x = []

for element in x:
    #print(element.to_pydatetime)
    ts = pd.Timestamp(element)
    #print(ts.to_pydatetime)
    processed_x.append(ts.to_pydatetime)

#print(processed_x)
 
dataframe = pd.DataFrame({'date_of_week': np.array(x),
                          'units': y })

#dataframe.set_index('date_of_week', inplace=True)


plt.plot(dataframe.date_of_week, dataframe.units)

plt.title('JFM Progress')

plt.xticks(rotation=30, ha='right')

plt.xlabel('Time')
plt.ylabel('Units')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 import numpy as np
#       5 # create dataframe
# ----> 7 x = jfm_data.date.to_list()
#       9 y = jfm_data.Unit.tolist()
#      11 processed_x = []
#
# NameError: name 'jfm_data' is not defined

# %%
import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]

# %%
import matplotlib.pyplot as plt 
#import datetime as dt

from datetime import datetime
import numpy as np

# create dataframe

x = jfm_data.date.to_list()

y = jfm_data.Unit.tolist()

processed_x = []

print(x)

for element in x:
    format_string = "%Y-%m-%d %H:%M:%S"
    print("elemnt:", element)
    #datetime_object = datetime.fromtimestamp(element)
    #processed_x.append(datetime_object)
    
print(processed_x)
 
dataframe = pd.DataFrame({'date_of_week': np.array(x),
                          'units': y })

#dataframe.set_index('date_of_week', inplace=True)


plt.plot(dataframe.date_of_week, dataframe.units)

plt.title('JFM Progress')

plt.xticks(rotation=30, ha='right')

plt.xlabel('Time')
plt.ylabel('Units')
# Out:
# [Timestamp('2022-06-09 00:00:00'), Timestamp('2022-06-16 00:00:00'), Timestamp('2020-06-23 00:00:00'), Timestamp('2022-06-30 00:00:00'), Timestamp('2022-07-07 00:00:00'), Timestamp('2022-07-14 00:00:00'), Timestamp('2022-07-21 00:00:00'), Timestamp('2022-07-28 00:00:00'), Timestamp('2022-08-04 00:00:00'), Timestamp('2022-08-11 00:00:00'), Timestamp('2022-08-18 00:00:00'), Timestamp('2022-07-25 00:00:00'), Timestamp('2022-09-01 00:00:00'), Timestamp('2022-09-08 00:00:00'), Timestamp('2022-09-15 00:00:00'), Timestamp('2022-09-22 00:00:00'), Timestamp('2022-09-29 00:00:00'), Timestamp('2022-10-06 00:00:00'), Timestamp('2022-10-13 00:00:00'), Timestamp('2022-10-21 00:00:00'), Timestamp('2022-09-28 00:00:00'), Timestamp('2022-11-03 00:00:00'), Timestamp('2022-11-10 00:00:00'), Timestamp('2022-11-17 00:00:00'), Timestamp('2022-11-24 00:00:00'), Timestamp('2022-12-01 00:00:00'), Timestamp('2022-12-08 00:00:00'), Timestamp('2022-12-15 00:00:00'), Timestamp('2022-12-22 00:00:00'), Timestamp('
# ...

# %%
import pandas as pd
df = pd.read_excel
'''
x = jfm_data.date.tolist()
for element in x:
    #ts = pd.Timestamp(element, tz=None)
    
    print("ts object:", element)
'''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/7y/4f_3_8x96c5bh2vppz_hvylh0000gp/T/ipykernel_67291/3872357703.py in ?()
#       1 import pandas as pd
# ----> 2 x = jfm_data.date.to_pydatetime()
#       3 for element in x:
#       4     #ts = pd.Timestamp(element, tz=None)
#       5
#
# ~/development/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_pydatetime'

# %%
import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]

# %%
jfm_data['date'] = pd.to_datetime(jfm_data["date"])

# %%
print(jfm_data['date'])
# Out:
# 0     2022-06-09
# 1     2022-06-16
# 2     2020-06-23
# 3     2022-06-30
# 4     2022-07-07
#          ...
# 104   2024-06-06
# 105   2024-06-13
# 106   2024-06-20
# 107   2024-06-26
# 108   2024-07-04
# Name: date, Length: 109, dtype: datetime64[ns]

# %%
from datetime import datetime
import numpy as np
import pandas as pd


jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)


# create dataframe

x = jfm_data['date']

y = jfm_data.Unit.tolist()

processed_x = []

print(x)

for element in x:
    format_string = "%Y-%m-%d %H:%M:%S"
    print("elemnt:", element)
    #datetime_object = datetime.fromtimestamp(element)
    #processed_x.append(datetime_object)
    
#print(processed_x)
 
dataframe = pd.DataFrame({'date_of_week': x,
                          'units': y })

#dataframe.set_index('date_of_week', inplace=True)


plt.plot(dataframe.date_of_week, dataframe.units)

plt.title('JFM Progress')

plt.xticks(rotation=30, ha='right')

plt.xlabel('Time')
plt.ylabel('Units')
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]
# 0     2022-06-09
# 1     2022-06-16
# 2     2020-06-23
# 3     2022-06-30
# 4     2022-07-07
#          ...
# 104   2024-06-06
# 105   2024-06-13
# 106   2024-06-20
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

date_time = ["2021-01-01", "2021-01-02", "2021-01-03"]
date_time = pd.to_datetime(date_time)
data = [1, 2, 3]

DF = pd.DataFrame()
DF['value'] = data
DF = DF.set_index(date_time)
plt.plot(DF)
plt.gcf().autofmt_xdate()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#data = pd.read_fwf('myfile.log',header=None,names=['time','amount'],widths=[27,5])
jfm_data.date = pd.to_datetime(jfm_data['date'], format='%Y-%m-%d %H:%M:%S.%f')
jfm_data.set_index(['date'],inplace=True)
jfm_data.plot()
# Out:
# <Axes: xlabel='date'>

# %%
import matplotlib.pyplot as plt 
#import datetime as dt

from datetime import datetime
import numpy as np

import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)

# create dataframe

x = jfm_data.date.to_list()

y = jfm_data.Unit.tolist()

processed_x = []

print(x)

inc = 0

for element in x:
    processed_x.append(inc)
    inc=inc+1
    
    
    
print(len(processed_x))
 
dataframe = pd.DataFrame({'date_of_week': np.array(processed_x),
                          'units': y })

#dataframe.set_index('date_of_week', inplace=True)


plt.plot(dataframe.date_of_week, dataframe.units)

plt.title('JFM Progress')

plt.xticks(rotation=30, ha='right')

plt.xlabel('Time')
plt.ylabel('Units')
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]
# ...

# %%
import matplotlib.pyplot as plt 
import datetime as dt

#from datetime import datetime
import numpy as np

import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)

# create dataframe

dates = jfm_data.date.to_list()

x = [dt.datetime.strptime(d,'%m/%d/%Y').date() for d in dates]
print(x)

y = jfm_data.Unit.tolist()
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 15
# ...

# %%
ts = pd.Timestamp('2020-03-14T15:32:52.192548651')
ts.strftime('%Y-%m-%d %X')
# Out:
# '2020-03-14 15:32:52'

# %%
import matplotlib.pyplot as plt 
import datetime as dt

#from datetime import datetime
import numpy as np

import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)

# create dataframe

dates = jfm_data.date.to_list()

x =[]

for date in dates:
    ts = pd.Timestamp(date)
    x.append(ts.strftime('%Y-%m-%d %X'))

y = jfm_data.Unit.tolist()
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]
# 2022-06-09 00:00:00
# 2022-06-16 00:00:00
# 2020-06-23 00:00:00
# 2022-06-30 00:00:00
# 2022-07-07 00:00:00
# 2022-07-14 00:00:00
# 2022-07-21 00:00:00
# 2022-07-28 00:00:00
# ...

# %%
dataframe = pd.DataFrame({'date_of_week': np.array(x),
                          'units': y })

#dataframe.set_index('date_of_week', inplace=True)


plt.plot(dataframe.date_of_week, dataframe.units)

plt.title('JFM Progress')

plt.xticks(rotation=30, ha='right')

plt.xlabel('Time')
plt.ylabel('Units')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataframe = pd.DataFrame({'date_of_week': np.array(x),
#       2                           'units': y })
#       4 #dataframe.set_index('date_of_week', inplace=True)
#       7 plt.plot(dataframe.date_of_week, dataframe.units)
#
# NameError: name 'x' is not defined

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
import matplotlib.pyplot as plt 
import datetime as dt

#from datetime import datetime
import numpy as np

import pandas as pd
jfm_data = pd.read_excel('/Users/imranahmed/Downloads/JFM.xlsx')
print(jfm_data)

# create dataframe

dates = jfm_data.date.tolist()

x =[]

for date in dates:
    ts = pd.Timestamp(date)
    x.append(ts.strftime('%Y-%m-%d'))

y = jfm_data.Unit.tolist()
print(x)
# Out:
#           date  read 1  read 2  Unit    Amt            comments
# 0   2022-06-09  204134  203792   342  17442                 NaN
# 1   2022-06-16  204523  204134   389  19839                 NaN
# 2   2020-06-23  204924  204523   401  20451                 NaN
# 3   2022-06-30  205309  204924   385  19635                 NaN
# 4   2022-07-07  205736  205309   427  21777                 NaN
# ..         ...     ...     ...   ...    ...                 ...
# 104 2024-06-06  238006  237760   246  12546  patra replacement
# 105 2024-06-13  238314  238006   308  15708                 NaN
# 106 2024-06-20  238568  238314   254  12954                 NaN
# 107 2024-06-26  238823  238568   255  13005                 NaN
# 108 2024-07-04  239099  238823   276  14076                 NaN
#
# [109 rows x 6 columns]
# ...

# %%
print(x)
# Out:
# ['2022-06-09', '2022-06-16', '2020-06-23', '2022-06-30', '2022-07-07', '2022-07-14', '2022-07-21', '2022-07-28', '2022-08-04', '2022-08-11', '2022-08-18', '2022-07-25', '2022-09-01', '2022-09-08', '2022-09-15', '2022-09-22', '2022-09-29', '2022-10-06', '2022-10-13', '2022-10-21', '2022-09-28', '2022-11-03', '2022-11-10', '2022-11-17', '2022-11-24', '2022-12-01', '2022-12-08', '2022-12-15', '2022-12-22', '2022-12-29', '2023-01-05', '2023-01-12', '2023-01-19', '2023-01-26', '2023-02-02', '2023-02-09', '2023-02-16', '2023-02-23', '2023-03-02', '2023-03-09', '2023-03-16', '2023-03-23', '2023-03-30', '2023-04-07', '2023-04-13', '2023-04-20', '2023-04-27', '2023-05-04', '2023-05-11', '2023-05-18', '2023-05-25', '2023-06-01', '2023-06-08', '2023-06-15', '2023-06-22', '2023-06-29', '2023-07-06', '2023-07-13', '2023-07-20', '2023-07-27', '2023-08-03', '2023-08-10', '2023-08-17', '2023-08-24', '2023-08-31', '2023-09-07', '2023-09-14', '2023-09-21', '2023-09-28', '2023-10-05', '2023-10-12', '20
# ...

# %%
dataframe = pd.DataFrame({'timestamp': np.array(dates),
                          'date_of_week': np.array(x),
                          'units': y })

#dataframe.set_index('date_of_week', inplace=True)


plt.figure(figsize=(30,12))

plt.plot(dataframe.date_of_week, dataframe.units)

plt.title('JFM Progress')

#plt.xticks([1,2,3,4])

plt.xlabel('Time')
plt.ylabel('Units')
# Out:
# Text(0, 0.5, 'Units')

# %%
date_dict = jfm_data.date.to_dict()

# %%
print(date_dict)
# Out:
# {0: Timestamp('2022-06-09 00:00:00'), 1: Timestamp('2022-06-16 00:00:00'), 2: Timestamp('2020-06-23 00:00:00'), 3: Timestamp('2022-06-30 00:00:00'), 4: Timestamp('2022-07-07 00:00:00'), 5: Timestamp('2022-07-14 00:00:00'), 6: Timestamp('2022-07-21 00:00:00'), 7: Timestamp('2022-07-28 00:00:00'), 8: Timestamp('2022-08-04 00:00:00'), 9: Timestamp('2022-08-11 00:00:00'), 10: Timestamp('2022-08-18 00:00:00'), 11: Timestamp('2022-07-25 00:00:00'), 12: Timestamp('2022-09-01 00:00:00'), 13: Timestamp('2022-09-08 00:00:00'), 14: Timestamp('2022-09-15 00:00:00'), 15: Timestamp('2022-09-22 00:00:00'), 16: Timestamp('2022-09-29 00:00:00'), 17: Timestamp('2022-10-06 00:00:00'), 18: Timestamp('2022-10-13 00:00:00'), 19: Timestamp('2022-10-21 00:00:00'), 20: Timestamp('2022-09-28 00:00:00'), 21: Timestamp('2022-11-03 00:00:00'), 22: Timestamp('2022-11-10 00:00:00'), 23: Timestamp('2022-11-17 00:00:00'), 24: Timestamp('2022-11-24 00:00:00'), 25: Timestamp('2022-12-01 00:00:00'), 26: Timestamp('2022
# ...

# %%
dataframe
# Out:
#     date_of_week  units
# 0     2022-06-09    342
# 1     2022-06-16    389
# 2     2020-06-23    401
# 3     2022-06-30    385
# 4     2022-07-07    427
# ..           ...    ...
# 104   2024-06-06    246
# 105   2024-06-13    308
# 106   2024-06-20    254
# 107   2024-06-26    255
# 108   2024-07-04    276
#
# [109 rows x 2 columns]

# %%
dataframe_1 = dataframe[0:48]

# %%
dataframe_1
# Out:
#     timestamp date_of_week  units
# 0  2022-06-09   2022-06-09    342
# 1  2022-06-16   2022-06-16    389
# 2  2020-06-23   2020-06-23    401
# 3  2022-06-30   2022-06-30    385
# 4  2022-07-07   2022-07-07    427
# 5  2022-07-14   2022-07-14    305
# 6  2022-07-21   2022-07-21    344
# 7  2022-07-28   2022-07-28    397
# 8  2022-08-04   2022-08-04    422
# 9  2022-08-11   2022-08-11    297
# 10 2022-08-18   2022-08-18    456
# 11 2022-07-25   2022-07-25    444
# 12 2022-09-01   2022-09-01    401
# 13 2022-09-08   2022-09-08    395
# 14 2022-09-15   2022-09-15    434
# 15 2022-09-22   2022-09-22    456
# 16 2022-09-29   2022-09-29    402
# 17 2022-10-06   2022-10-06    412
# 18 2022-10-13   2022-10-13    322
# 19 2022-10-21   2022-10-21    383
# 20 2022-09-28   2022-09-28    291
# 21 2022-11-03   2022-11-03    350
# 22 2022-11-10   2022-11-10    293
# 23 2022-11-17   2022-11-17    216
# 24 2022-11-24   2022-11-24    324
# 25 2022-12-01   2022-12-01    375
# ...

# %%
import matplotlib.dates as mdates

plt.figure(figsize=(20,12))

#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=3))
#plt.gca().xaxis.set_major_locator(interval=3)

plt.plot(dataframe_1.date_of_week, dataframe_1.units)

plt.title('JFM Progress')

#plt.xticks([1,2,3,4])

plt.xlabel('Time')
plt.ylabel('Units')
# Out:
# Text(0, 0.5, 'Units')

# %%
dataframe
# Out:
#      timestamp date_of_week  units
# 0   2022-06-09   2022-06-09    342
# 1   2022-06-16   2022-06-16    389
# 2   2020-06-23   2020-06-23    401
# 3   2022-06-30   2022-06-30    385
# 4   2022-07-07   2022-07-07    427
# ..         ...          ...    ...
# 104 2024-06-06   2024-06-06    246
# 105 2024-06-13   2024-06-13    308
# 106 2024-06-20   2024-06-20    254
# 107 2024-06-26   2024-06-26    255
# 108 2024-07-04   2024-07-04    276
#
# [109 rows x 3 columns]

# %%
date_range = dataframe.loc('2022-01-02':'2022-01-03')
# Out:
#   Cell In[51], line 1
#     date_range = dataframe.loc('2022-01-02':'2022-01-03')
#                                            ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
dataframe['timestamp'] = pd.to_datetime(dataframe['timestamp'])
start_date = '2023-01-01'
end_date = '2023-12-31'
mask = (dataframe['timestamp'] > start_date) & (dataframe['timestamp'] < end_date)

filtered_dataframe = dataframe.loc[mask]
filtered_dataframe
# Out:
#     timestamp date_of_week  units
# 30 2023-01-05   2023-01-05    379
# 31 2023-01-12   2023-01-12    422
# 32 2023-01-19   2023-01-19    373
# 33 2023-01-26   2023-01-26    314
# 34 2023-02-02   2023-02-02    327
# 35 2023-02-09   2023-02-09    288
# 36 2023-02-16   2023-02-16    361
# 37 2023-02-23   2023-02-23    379
# 38 2023-03-02   2023-03-02    307
# 39 2023-03-09   2023-03-09    252
# 40 2023-03-16   2023-03-16    341
# 41 2023-03-23   2023-03-23    573
# 42 2023-03-30   2023-03-30    212
# 43 2023-04-07   2023-04-07    189
# 44 2023-04-13   2023-04-13    177
# 45 2023-04-20   2023-04-20    243
# 46 2023-04-27   2023-04-27    183
# 47 2023-05-04   2023-05-04    293
# 48 2023-05-11   2023-05-11    237
# 49 2023-05-18   2023-05-18    293
# 50 2023-05-25   2023-05-25    293
# 51 2023-06-01   2023-06-01    256
# 52 2023-06-08   2023-06-08    215
# 53 2023-06-15   2023-06-15    316
# 54 2023-06-22   2023-06-22    308
# 55 2023-06-29   2023-06-29    319
# ...
